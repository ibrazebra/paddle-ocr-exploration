# %%
from paddleocr import PaddleOCR,draw_ocr
import os

os.chdir("/home/ibrazebra/src/github.com/PaddleOCR/ppocr_img")

#ocr = PaddleOCR(use_angle_cls=True, lang='en') # need to run only once to download and load model into memory

# %%
# !pwd
# Out:
# /home/ibrazebra/src/github.com/PaddleOCR/ppocr_img

# %%
# %pip install --upgrade pip
# %pip install paddleocr

# %%
# !paddleocr --image_dir ./imgs_en/img_12.jpg --use_angle_cls true --lang en --use_gpu false
# Out:
# /bin/zsh: /home/ibrazebra/miniconda3/envs/paddle_env/lib/libtinfo.so.6: no version information available (required by /bin/zsh)
# [2023/12/10 03:04:52] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ibrazebra/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ibrazebra/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir='./imgs_en/img_12.jpg', image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages/paddleocr/ppocr/utils/en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ibrazebra/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [2023/12/10 03:04:52] ppocr INFO: **********./imgs_en/img_12.jpg**********
# [2023/12/10 03:04:53] ppocr DEBUG: dt_boxes num : 11, elapsed : 0.22370195388793945
# [2023/12/10 03:04:53] ppocr DEBUG: cls num  : 11, elapsed : 0.030314922332763672
# [2023/12/10 03:04:54] ppocr DEBUG: rec_res num  : 11, elapsed : 1.4577648639678955
# [2023/12/10 03:04:54] ppocr INFO: [[[441.0, 174.0], [1166.0, 176.0], [1165.0, 222.0], [441.0, 221.0]], ('ACKNOWLEDGEMENTS', 0.9974855184555054)]
# [2023/12/10 03:04:54] ppocr INFO: [[[403.0, 346.0], [1204.0, 348.0], [1204.0, 384.0], [402.0, 383.0]], ('We would like to thank all the designers and', 0.968330979347229)]
# [2023/12/10 03:04:54] ppocr INFO: [[[403.0, 396.0], [1204.0, 398.0], [1204.0, 434.0], [402.0, 433.0]], ('contributors who have been involved in the', 0.9776102900505066)]
# [2023/12/10 03:04:54] ppocr INFO: [[[399.0, 446.0], [1207.0, 443.0], [1208.0, 484.0], [399.0, 488.0]], ('production of this book; their contributions', 0.9866490960121155)]
# [2023/12/10 03:04:54] ppocr INFO: [[[401.0, 500.0], [1208.0, 500.0], [1208.0, 534.0], [401.0, 534.0]], ('have been indispensable to its creation.We', 0.9628525972366333)]
# [2023/12/10 03:04:54] ppocr INFO: [[[399.0, 550.0], [1209.0, 548.0], [1209.0, 583.0], [399.0, 584.0]], ('would also like to express our gratitude to all', 0.9740485548973083)]
# [2023/12/10 03:04:54] ppocr INFO: [[[399.0, 600.0], [1207.0, 598.0], [1208.0, 634.0], [399.0, 636.0]], ('the producers for their invaluable opinions', 0.9963331818580627)]
# [2023/12/10 03:04:54] ppocr INFO: [[[399.0, 648.0], [1207.0, 646.0], [1208.0, 686.0], [399.0, 688.0]], ('and assistance throughout this project. And to', 0.994373083114624)]
# [2023/12/10 03:04:54] ppocr INFO: [[[399.0, 702.0], [1209.0, 698.0], [1209.0, 734.0], [399.0, 738.0]], ('the many others whose names are not credited', 0.977229118347168)]
# [2023/12/10 03:04:54] ppocr INFO: [[[399.0, 750.0], [1211.0, 750.0], [1211.0, 789.0], [399.0, 789.0]], ('but have made specific input in this book, we', 0.9979288578033447)]
# [2023/12/10 03:04:54] ppocr INFO: [[[397.0, 802.0], [1090.0, 800.0], [1090.0, 839.0], [397.0, 841.0]], ('thank you for your continuous support.', 0.9981997609138489)]

# %%
# !code --version
# Out:
# 1.81.1
# 6c3e3dba23e8fadc360aed75ce363ba185c49794
# x64

# %%
# !python --version
# Out:
# Python 3.8.18

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 8.12.0
# ipykernel        : 6.26.0
# ipywidgets       : 8.1.1
# jupyter_client   : 8.6.0
# jupyter_core     : 5.5.0
# jupyter_server   : 2.10.0
# jupyterlab       : 4.0.8
# nbclient         : 0.9.0
# nbconvert        : 7.11.0
# nbformat         : 5.9.2
# notebook         : 7.0.6
# qtconsole        : 5.5.0
# traitlets        : 5.13.0

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            31Gi       2.1Gi        20Gi       3.0Mi       8.8Gi        28Gi
# Swap:          8.0Gi          0B       8.0Gi

# %%
# !python -m pip install --upgrade pip
# !python -m pip install --upgrade jupyter
# Out:
# Requirement already satisfied: pip in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (23.3.1)
# Requirement already satisfied: jupyter in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (1.0.0)
# Requirement already satisfied: notebook in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter) (7.0.6)
# Requirement already satisfied: qtconsole in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter) (5.5.0)
# Requirement already satisfied: jupyter-console in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter) (7.11.0)
# Requirement already satisfied: ipykernel in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter) (6.26.0)
# Requirement already satisfied: ipywidgets in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter) (8.1.1)
# Requirement already satisfied: comm>=0.1.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (8.12.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (5.5.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (1.5.8)
# Requirement already satisfied: packaging in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (23.2)
# Requirement already satisfied: psutil in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipykernel->jupyter) (5.13.0)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipywidgets->jupyter) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipywidgets->jupyter) (3.0.9)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-console->jupyter) (3.0.39)
# Requirement already satisfied: pygments in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-console->jupyter) (2.16.1)
# Requirement already satisfied: beautifulsoup4 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (6.8.0)
# Requirement already satisfied: jinja2>=3.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (3.1.2)
# Requirement already satisfied: jupyterlab-pygments in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (0.2.2)
# Requirement already satisfied: markupsafe>=2.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (2.1.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (0.9.0)
# Requirement already satisfied: nbformat>=5.7 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbconvert->jupyter) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from notebook->jupyter) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from notebook->jupyter) (2.25.1)
# Requirement already satisfied: jupyterlab<5,>=4.0.2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from notebook->jupyter) (4.0.8)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from notebook->jupyter) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: six>=1.9.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (1.16.0)
# Requirement already satisfied: webencodings in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: zipp>=0.5 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from importlib-metadata>=3.6->nbconvert->jupyter) (3.17.0)
# Requirement already satisfied: backcall in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: decorator in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: pickleshare in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: stack-data in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.2)
# Requirement already satisfied: typing-extensions in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: pexpect>4.3 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from ipython>=7.23.1->ipykernel->jupyter) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.11.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (4.0.0)
# Requirement already satisfied: argon2-cffi in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.4.4)
# Requirement already satisfied: overrides in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.18.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter) (1.6.4)
# Requirement already satisfied: async-lru>=1.0.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.4)
# Requirement already satisfied: importlib-resources>=1.4 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (6.1.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.2.0)
# Requirement already satisfied: tomli in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab<5,>=4.0.2->notebook->jupyter) (2.0.1)
# Requirement already satisfied: babel>=2.10 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.13.1)
# Requirement already satisfied: json5>=0.9.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.9.14)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.31.0)
# Requirement already satisfied: fastjsonschema in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.18.1)
# Requirement already satisfied: wcwidth in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter) (0.2.9)
# Requirement already satisfied: soupsieve>1.2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: idna>=2.8 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.1.3)
# Requirement already satisfied: pytz>=2015.7 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.1)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (1.3.10)
# Requirement already satisfied: referencing>=0.28.4 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (0.12.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (6.0.1)
# Requirement already satisfied: rfc3339-validator in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter) (2023.7.22)
# Requirement already satisfied: argon2-cffi-bindings in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (21.2.0)
# Requirement already satisfied: executing>=1.2.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (2.4.1)
# Requirement already satisfied: pure-eval in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter) (0.2.2)
# Requirement already satisfied: fqdn in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.4)
# Requirement already satisfied: uri-template in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.16.0)
# Requirement already satisfied: pycparser in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook->jupyter) (2.8.19.14)

# %%
# 1. Import PaddleOCR class from paddleocr
from paddleocr import PaddleOCR

# 2. Declare the PaddleOCR class
ocr = PaddleOCR(use_angle_cls=True, lang='en', use_gpu=False)
img_path ='./imgs_en/img_12.jpg'

# 3. Perform inference
#`--rec`` false means no recognition is used, only text detection is performed
result = ocr.ocr(img_path, rec=False)
print(result)
# Out:
# [2023/12/10 03:19:48] ppocr DEBUG: Namespace(alpha=1.0, alphacolor=(255, 255, 255), benchmark=False, beta=1.0, binarize=False, cls_batch_num=6, cls_image_shape='3, 48, 192', cls_model_dir='/home/ibrazebra/.paddleocr/whl/cls/ch_ppocr_mobile_v2.0_cls_infer', cls_thresh=0.9, cpu_threads=10, crop_res_save_dir='./output', det=True, det_algorithm='DB', det_box_type='quad', det_db_box_thresh=0.6, det_db_score_mode='fast', det_db_thresh=0.3, det_db_unclip_ratio=1.5, det_east_cover_thresh=0.1, det_east_nms_thresh=0.2, det_east_score_thresh=0.8, det_limit_side_len=960, det_limit_type='max', det_model_dir='/home/ibrazebra/.paddleocr/whl/det/en/en_PP-OCRv3_det_infer', det_pse_box_thresh=0.85, det_pse_min_area=16, det_pse_scale=1, det_pse_thresh=0, det_sast_nms_thresh=0.2, det_sast_score_thresh=0.5, draw_img_save_dir='./inference_results', drop_score=0.5, e2e_algorithm='PGNet', e2e_char_dict_path='./ppocr/utils/ic15_dict.txt', e2e_limit_side_len=768, e2e_limit_type='max', e2e_model_dir=None, e2e_pgnet_mode='fast', e2e_pgnet_score_thresh=0.5, e2e_pgnet_valid_set='totaltext', enable_mkldnn=False, fourier_degree=5, gpu_id=0, gpu_mem=500, help='==SUPPRESS==', image_dir=None, image_orientation=False, invert=False, ir_optim=True, kie_algorithm='LayoutXLM', label_list=['0', '180'], lang='en', layout=True, layout_dict_path=None, layout_model_dir=None, layout_nms_threshold=0.5, layout_score_threshold=0.5, max_batch_size=10, max_text_length=25, merge_no_span_structure=True, min_subgraph_size=15, mode='structure', ocr=True, ocr_order_method=None, ocr_version='PP-OCRv4', output='./output', page_num=0, precision='fp32', process_id=0, re_model_dir=None, rec=True, rec_algorithm='SVTR_LCNet', rec_batch_num=6, rec_char_dict_path='/home/ibrazebra/miniconda3/envs/paddle_env/lib/python3.8/site-packages/paddleocr/ppocr/utils/en_dict.txt', rec_image_inverse=True, rec_image_shape='3, 48, 320', rec_model_dir='/home/ibrazebra/.paddleocr/whl/rec/en/en_PP-OCRv4_rec_infer', recovery=False, save_crop_res=False, save_log_path='./log_output/', scales=[8, 16, 32], ser_dict_path='../train_data/XFUND/class_list_xfun.txt', ser_model_dir=None, show_log=True, sr_batch_num=1, sr_image_shape='3, 32, 128', sr_model_dir=None, structure_version='PP-StructureV2', table=True, table_algorithm='TableAttn', table_char_dict_path=None, table_max_len=488, table_model_dir=None, total_process_num=1, type='ocr', use_angle_cls=True, use_dilation=False, use_gpu=False, use_mp=False, use_npu=False, use_onnx=False, use_pdf2docx_api=False, use_pdserving=False, use_space_char=True, use_tensorrt=False, use_visual_backbone=True, use_xpu=False, vis_font_path='./doc/fonts/simfang.ttf', warmup=False)
# [[[[397.0, 802.0], [1090.0, 800.0], [1090.0, 839.0], [397.0, 841.0]], [[399.0, 750.0], [1211.0, 750.0], [1211.0, 789.0], [399.0, 789.0]], [[399.0, 702.0], [1209.0, 698.0], [1209.0, 734.0], [399.0, 738.0]], [[399.0, 648.0], [1207.0, 646.0], [1208.0, 686.0], [399.0, 688.0]], [[399.0, 600.0], [1207.0, 598.0], [1208.0, 634.0], [399.0, 636.0]], [[399.0, 550.0], [1209.0, 548.0], [1209.0, 583.0], [399.0, 584.0]], [[401.0, 500.0], [1208.0, 500.0], [1208.0, 534.0], [401.0, 534.0]], [[399.0, 446.0], [1207.0, 443.0], [1208.0, 484.0], [399.0, 488.0]], [[403.0, 396.0], [1204.0, 398.0], [1204.0, 434.0], [402.0, 433.0]], [[403.0, 346.0], [1204.0, 348.0], [1204.0, 384.0], [402.0, 383.0]], [[441.0, 174.0], [1166.0, 176.0], [1165.0, 222.0], [441.0, 221.0]]]]

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# When using matplotlib.pyplot to draw in the notebook, you need to add this command to display
# %matplotlib inline

boxes = result[0]  # Extracting the bounding boxes from the result

# 4. Visual inspection results
image = cv2.imread(img_path)

for box in boxes:
    # Reshape the box vertices
    box = np.reshape(np.array(box), [-1, 2]).astype(np.int64)

    image = cv2.polylines(np.array(image), [box], isClosed=True, color=(255, 0, 0), thickness=2)

# Draw the read picture
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
